# %%
from RAG_model.evaluation.evaluation import main as evaluate
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]

# %%
from RAG_model.evaluation.model_analysis import run_config
from RAG_model.ingestion.config import BASELINE_RUN_CONFIG

# %%
detailed_questions, summary = await evaluate(BASELINE_RUN_CONFIG, retrieval_only=True)
# Out:
# Starting to create the parquet file.
# Start the Ingestion process.
# SEC html ingestion Complete
# Chunking step Complete
# Embedding Step Complete
# Starting to create the Qdrant database.
# Created collection: sec_filings_openai_text-embedding-3-small_v2_3
# Stored 100/9522 chunks
# Stored 200/9522 chunks
# Stored 300/9522 chunks
# Stored 400/9522 chunks
# Stored 500/9522 chunks
# Stored 600/9522 chunks
# Stored 700/9522 chunks
# Stored 800/9522 chunks
# Stored 900/9522 chunks
# Stored 1000/9522 chunks
# Stored 1100/9522 chunks
# Stored 1200/9522 chunks
# Stored 1300/9522 chunks
# Stored 1400/9522 chunks
# Stored 1500/9522 chunks
# Stored 1600/9522 chunks
# Stored 1700/9522 chunks
# Stored 1800/9522 chunks
# Stored 1900/9522 chunks
# Stored 2000/9522 chunks
# Stored 2100/9522 chunks
# Stored 2200/9522 chunks
# Stored 2300/9522 chunks
# Stored 2400/9522 chunks
# Stored 2500/9522 chunks
# Stored 2600/9522 chunks
# Stored 2700/9522 chunks
# Stored 2800/9522 chunks
# ...

# %%
summary
# Out:
#            scope  total_questions  answerable_questions  \
# 0  All questions               40                    32
# 1           Hard               21                    18
# 2         Medium               19                    14
#
#    unanswerable_questions  correct_answers overall_answer_accuracy  \
# 0                       8                0                    None
# 1                       3                0                    None
# 2                       5                0                    None
#
#    document_hit_rate_at_k  mean_document_recall_at_k       mrr  \
# 0                0.718750                   0.843750  0.368893
# 1                0.666667                   0.805556  0.279619
# 2                0.785714                   0.892857  0.483673
#
#    answerable_correct_answers answerable_answer_accuracy  \
# 0                           0                       None
# 1                           0                       None
# ...

# %%
detailed_questions, summary = await evaluate(BASELINE_RUN_CONFIG, retrieval_only=True)
# Out:
# Parquet file already exists.
# Collection already created.
# ...
# Questions [openai/gpt-5.6-luna]: 100%|##############################| 40/40 [07:08<00:00, 10.72s/it] | Complete

# %%
summary
# Out:
#            scope  total_questions  answerable_questions  \
# 0  All questions               40                    32
# 1           Hard               21                    18
# 2         Medium               19                    14
#
#    unanswerable_questions  correct_answers overall_answer_accuracy  \
# 0                       8                0                    None
# 1                       3                0                    None
# 2                       5                0                    None
#
#    document_hit_rate_at_k  mean_document_recall_at_k       mrr  \
# 0                0.781250                   0.812500  0.293249
# 1                0.666667                   0.722222  0.201532
# 2                0.928571                   0.928571  0.411170
#
#    answerable_correct_answers answerable_answer_accuracy  \
# 0                           0                       None
# 1                           0                       None
# ...
